# %%
from wordcloud import WordCloud
import numpy as np

import matplotlib.pyplot as plt
import PIL.Image
import pandas as pd

text ="HELLO WORLD"

wc=WordCloud().generate(text)
plt.imshow(wc)
plt.axis("off")
plt.show()

# %%
text=open('python.txt','r').read()
wc=WordCloud().generate(text)
plt.imshow(wc)
plt.axis("off")
plt.show()

# %%
text=open('python.txt','r').read()
wc=WordCloud(stopwords=['Python']).generate(text)
plt.imshow(wc)
plt.axis("off")
plt.show()

# %%
from wordcloud import WordCloud,STOPWORDS
import numpy as np
import matplotlib.pyplot as plt
import PIL.Image

text=open('python.txt','r').read()

wc=WordCloud(stopwords=STOPWORDS).generate(text)
plt.imshow(wc)
plt.axis("off")
plt.show()

# %%
python_mask=np.array(PIL.Image.open('python2.jpeg'))

wc=WordCloud(stopwords=STOPWORDS,
            mask=python_mask,
            background_color='white'
            ).generate(text)
plt.imshow(wc)
plt.axis("off")
plt.show()

# %%
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt


data = pd.read_csv('AnimeQuotes.csv')



text = ' '.join(data['Quote'])  # Assuming 'text_column' contains the text data
wordcloud = WordCloud(width=800, height=400, background_color='black').generate(text)


plt.figure(figsize=(10, 5))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
